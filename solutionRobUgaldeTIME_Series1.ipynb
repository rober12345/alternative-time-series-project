# %%
import pandas as pd

total_data = pd.read_csv("sales.csv")

total_data.head()
# Out:
#                          date      sales
# 0  2022-09-03 17:10:08.079328  55.292157
# 1  2022-09-04 17:10:08.079328  53.803211
# 2  2022-09-05 17:10:08.079328  58.141693
# 3  2022-09-06 17:10:08.079328  64.530899
# 4  2022-09-07 17:10:08.079328  66.013633

# %% [markdown]
# transform date to object

# %%
total_data["date"] = pd.to_datetime(total_data.date)
total_data = total_data.set_index("date")
ts_total = total_data["sales"]
ts_total.head()
# Out:
# date
# 2022-09-03 17:10:08.079328    55.292157
# 2022-09-04 17:10:08.079328    53.803211
# 2022-09-05 17:10:08.079328    58.141693
# 2022-09-06 17:10:08.079328    64.530899
# 2022-09-07 17:10:08.079328    66.013633
# Name: sales, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axis = plt.subplots(figsize = (10, 5))

sns.lineplot(data = ts_total)

plt.tight_layout()

plt.show()

# %% [markdown]
# construct and analyze the time series

# %%
from statsmodels.tsa.stattools import adfuller

def test_stationarity(timeseries):
    print("Dickey-Fuller test results:")
    dftest = adfuller(timeseries, autolag = "AIC")
    dfoutput = pd.Series(dftest[0:4], index = ["Test Statistic", "p-value", "#Lags Used", "Number of Observations Used"])
    for key,value in dftest[4].items():
        dfoutput["Critical Value (%s)"%key] = value
    return dfoutput

test_stationarity(ts_total)
# Out:
# Dickey-Fuller test results:
# Test Statistic                   0.545414
# p-value                          0.986190
# #Lags Used                      13.000000
# Number of Observations Used    352.000000
# Critical Value (1%)             -3.449065
# Critical Value (5%)             -2.869786
# Critical Value (10%)            -2.571163
# dtype: float64

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

decomposition = seasonal_decompose(ts_total)
decomposition

# %%
trend = decomposition.trend

fig, axis = plt.subplots(figsize = (10, 5))

sns.lineplot(data = ts_total)
sns.lineplot(data = trend)

plt.tight_layout()

plt.show()

# %%
seasonal = decomposition.seasonal

fig, axis = plt.subplots(figsize = (10, 5))

sns.lineplot(data = ts_total)
sns.lineplot(data = seasonal)

plt.tight_layout()

plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

def test_stationarity(timeseries):
    print("Dickey-Fuller test results:")
    dftest = adfuller(timeseries, autolag = "AIC")
    dfoutput = pd.Series(dftest[0:4], index = ["Test Statistic", "p-value", "#Lags Used", "Number of Observations Used"])
    for key,value in dftest[4].items():
        dfoutput["Critical Value (%s)"%key] = value
    return dfoutput

test_stationarity(ts_total)
# Out:
# Dickey-Fuller test results:
# Test Statistic                   0.545414
# p-value                          0.986190
# #Lags Used                      13.000000
# Number of Observations Used    352.000000
# Critical Value (1%)             -3.449065
# Critical Value (5%)             -2.869786
# Critical Value (10%)            -2.571163
# dtype: float64

# %% [markdown]
# pvalue is 0.98  , higher than 0.05, so the series is not stationary. no transformation is needed.

# %%
residual = decomposition.resid

fig, axis = plt.subplots(figsize = (10, 5))

sns.lineplot(data = ts_total)
sns.lineplot(data = residual)

plt.tight_layout()

plt.show()

# %% [markdown]
# Autocorrelation analysis

# %%
from statsmodels.graphics.tsaplots import plot_acf

plot_acf(ts_total)

plt.tight_layout()

plt.show()

# %% [markdown]
# ARIMA TRAINING :  Auto Regressive Integrated Moving Average model.  To make future predictions.

# %%
from pmdarima import auto_arima

model = auto_arima(ts_total, seasonal = False, trace = True, m = 7)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from pmdarima import auto_arima
#       3 model = auto_arima(ts_total, seasonal = False, trace = True, m = 7)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pmdarima/__init__.py:52
#      49 from . import __check_build
#      51 # Stuff we want at top-level
# ---> 52 from .arima import auto_arima, ARIMA, AutoARIMA, StepwiseContext, decompose
#      53 from .utils import acf, autocorr_plot, c, pacf, plot_acf, plot_pacf, \
#      54     tsdisplay
#      55 from .utils._show_versions import show_versions
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pmdarima/arima/__init__.py:5
#       1 # -*- coding: utf-8 -*-
#       2 #
#       3 # Author: Taylor Smith <taylor.smith@alkaline-ml.com>
# ----> 5 from .approx import *
#       6 from .arima import *
# ...

# %%
import numpy
import scipy
import pmdarima

print("NumPy version:", numpy.__version__)
print("SciPy version:", scipy.__version__)
print("pmdarima version:", pmdarima.__version__)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 3
#       1 import numpy
#       2 import scipy
# ----> 3 import pmdarima
#       5 print("NumPy version:", numpy.__version__)
#       6 print("SciPy version:", scipy.__version__)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pmdarima/__init__.py:52
#      49 from . import __check_build
#      51 # Stuff we want at top-level
# ---> 52 from .arima import auto_arima, ARIMA, AutoARIMA, StepwiseContext, decompose
#      53 from .utils import acf, autocorr_plot, c, pacf, plot_acf, plot_pacf, \
#      54     tsdisplay
#      55 from .utils._show_versions import show_versions
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pmdarima/arima/__init__.py:5
#       1 # -*- coding: utf-8 -*-
#       2 #
#       3 # Author: Taylor Smith <taylor.smith@alkaline-ml.com>
# ...

# %%
import numpy
import scipy
import pmdarima

print("NumPy version:", numpy.__version__)
print("SciPy version:", scipy.__version__)
print("pmdarima version:", pmdarima.__version__)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 3
#       1 import numpy
#       2 import scipy
# ----> 3 import pmdarima
#       5 print("NumPy version:", numpy.__version__)
#       6 print("SciPy version:", scipy.__version__)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pmdarima/__init__.py:52
#      49 from . import __check_build
#      51 # Stuff we want at top-level
# ---> 52 from .arima import auto_arima, ARIMA, AutoARIMA, StepwiseContext, decompose
#      53 from .utils import acf, autocorr_plot, c, pacf, plot_acf, plot_pacf, \
#      54     tsdisplay
#      55 from .utils._show_versions import show_versions
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pmdarima/arima/__init__.py:5
#       1 # -*- coding: utf-8 -*-
#       2 #
#       3 # Author: Taylor Smith <taylor.smith@alkaline-ml.com>
# ...

# %%
import numpy
import scipy
import pmdarima

print("NumPy version:", numpy.__version__)
print("SciPy version:", scipy.__version__)
print("pmdarima version:", pmdarima.__version__)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 3
#       1 import numpy
#       2 import scipy
# ----> 3 import pmdarima
#       5 print("NumPy version:", numpy.__version__)
#       6 print("SciPy version:", scipy.__version__)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pmdarima/__init__.py:52
#      49 from . import __check_build
#      51 # Stuff we want at top-level
# ---> 52 from .arima import auto_arima, ARIMA, AutoARIMA, StepwiseContext, decompose
#      53 from .utils import acf, autocorr_plot, c, pacf, plot_acf, plot_pacf, \
#      54     tsdisplay
#      55 from .utils._show_versions import show_versions
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pmdarima/arima/__init__.py:5
#       1 # -*- coding: utf-8 -*-
#       2 #
#       3 # Author: Taylor Smith <taylor.smith@alkaline-ml.com>
# ...

# %%
print("NumPy version:", numpy.__version__)
print("SciPy version:", scipy.__version__)
print("pmdarima version:", pmdarima.__version__)
# Out:
# NumPy version: 2.2.2
# SciPy version: 1.15.1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 print("NumPy version:", numpy.__version__)
#       2 print("SciPy version:", scipy.__version__)
# ----> 3 print("pmdarima version:", pmdarima.__version__)
#
# NameError: name 'pmdarima' is not defined

# %%
import numpy
print(numpy.__version__)  # It should print: 1.26.4
# Out:
# 2.2.2

# %%
import numpy
import scipy
import pmdarima

print("NumPy version:", numpy.__version__)  # Should print: 1.26.4
print("SciPy version:", scipy.__version__)  # Should be around 1.11.x
print("pmdarima version:", pmdarima.__version__)  # Should work without errors
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[37], line 3
#       1 import numpy
#       2 import scipy
# ----> 3 import pmdarima
#       5 print("NumPy version:", numpy.__version__)  # Should print: 1.26.4
#       6 print("SciPy version:", scipy.__version__)  # Should be around 1.11.x
#
# ModuleNotFoundError: No module named 'pmdarima'

# %%
import pmdarima
print("pmdarima version:", pmdarima.__version__)  # Should work without errors
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 import pmdarima
#       2 print("pmdarima version:", pmdarima.__version__)  # Should work without errors
#
# ModuleNotFoundError: No module named 'pmdarima'

# %%
import numpy
import pmdarima

print("NumPy version:", numpy.__version__)  # MUST still be 1.26.4
print("pmdarima version:", pmdarima.__version__)  # Should print 1.8.5
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[38], line 2
#       1 import numpy
# ----> 2 import pmdarima
#       4 print("NumPy version:", numpy.__version__)  # MUST still be 1.26.4
#       5 print("pmdarima version:", pmdarima.__version__)  # Should print 1.8.5
#
# ModuleNotFoundError: No module named 'pmdarima'

# %%
import numpy
import pmdarima

print("NumPy version:", numpy.__version__)  # MUST still be 1.26.4
print("pmdarima version:", pmdarima.__version__)  # Should print 1.8.5
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[39], line 2
#       1 import numpy
# ----> 2 import pmdarima
#       4 print("NumPy version:", numpy.__version__)  # MUST still be 1.26.4
#       5 print("pmdarima version:", pmdarima.__version__)  # Should print 1.8.5
#
# ModuleNotFoundError: No module named 'pmdarima'

# %%
import numpy
print(numpy.__version__)  # MUST be 1.26.4
# Out:
# 2.2.2

# %%
import numpy
print(numpy.__version__)  # MUST be 1.26.4
# Out:
# 1.26.4

# %%
from pmdarima import auto_arima

model = auto_arima(ts_total, seasonal = False, trace = True, m = 7)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from pmdarima import auto_arima
#       3 model = auto_arima(ts_total, seasonal = False, trace = True, m = 7)
#
# ModuleNotFoundError: No module named 'pmdarima'

# %%
import pmdarima

# %% [markdown]
# imported pmdarima correctly

# %%
from pmdarima import auto_arima

model = auto_arima(ts_total, seasonal = False, trace = True, m = 7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 from pmdarima import auto_arima
# ----> 3 model = auto_arima(ts_total, seasonal = False, trace = True, m = 7)
#
# NameError: name 'ts_total' is not defined

# %%
import pandas as pd

total_data = pd.read_csv("sales.csv")
total_data["date"] = pd.to_datetime(total_data.date)
total_data = total_data.set_index("date")
ts_total = total_data["sales"]



from statsmodels.tsa.stattools import adfuller

def test_stationarity(timeseries):
    print("Dickey-Fuller test results:")
    dftest = adfuller(timeseries, autolag = "AIC")
    dfoutput = pd.Series(dftest[0:4], index = ["Test Statistic", "p-value", "#Lags Used", "Number of Observations Used"])
    for key,value in dftest[4].items():
        dfoutput["Critical Value (%s)"%key] = value
    return dfoutput

test_stationarity(ts_total)
# Out:
# Dickey-Fuller test results:
# Test Statistic                   0.545414
# p-value                          0.986190
# #Lags Used                      13.000000
# Number of Observations Used    352.000000
# Critical Value (1%)             -3.449065
# Critical Value (5%)             -2.869786
# Critical Value (10%)            -2.571163
# dtype: float64

# %%
from pmdarima import auto_arima

model = auto_arima(ts_total, seasonal = False, trace = True, m = 7)
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/pmdarima/arima/_validation.py:62: UserWarning: m (7) set for non-seasonal fit. Setting to 0
#   warnings.warn("m (%i) set for non-seasonal fit. Setting to 0" % m)
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ...

# %% [markdown]
# The best model was ARIMA(1,1,1)
# Predict with the test set  60 points, to predict 60 periods in the future.

# %%
forecast = model.predict(60)
forecast
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2023-09-04 17:10:08.079328    1002.158148
# 2023-09-05 17:10:08.079328    1004.831668
# 2023-09-06 17:10:08.079328    1007.423289
# 2023-09-07 17:10:08.079328    1010.021630
# 2023-09-08 17:10:08.079328    1012.619419
# 2023-09-09 17:10:08.079328    1015.217253
# 2023-09-10 17:10:08.079328    1017.815084
# 2023-09-11 17:10:08.079328    1020.412915
# 2023-09-12 17:10:08.079328    1023.010746
# 2023-09-13 17:10:08.079328    1025.608577
# 2023-09-14 17:10:08.079328    1028.206408
# 2023-09-15 17:10:08.079328    1030.804239
# 2023-09-16 17:10:08.079328    1033.402070
# 2023-09-17 17:10:08.079328    1035.999902
# 2023-09-18 17:10:08.079328    1038.597733
# 2023-09-19 17:10:08.079328    1041.195564
# 2023-09-20 17:10:08.079328    1043.793395
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axis = plt.subplots(figsize = (10, 5))

sns.lineplot(data = ts_total)
sns.lineplot(data = forecast, c = "green")

plt.tight_layout()

plt.show()
